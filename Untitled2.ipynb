# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
s=0
t=s
n=10000
media=2

# %%
Lista=[]
for i in range(n):
   U=random.random()
   r=-(1/media)*np.log(U)
   Lista.append(r)

# %%
plt.hist(Lista,bins=500,color="red",rwidth=0.5)
plt.show()
