# %%
import numpy as np

# %%
a=121
b=1
m=256
r=17

# %%
print("i \t r_i")
for i in range(1,260):
 r=np.mod(a+b*r,m)
 print(i,"\t",round(r,5))
# Out:
# i 	 r_i
# 1 	 138
# 2 	 3
# 3 	 124
# 4 	 245
# 5 	 110
# 6 	 231
# 7 	 96
# 8 	 217
# 9 	 82
# 10 	 203
# 11 	 68
# 12 	 189
# 13 	 54
# 14 	 175
# 15 	 40
# 16 	 161
# 17 	 26
# 18 	 147
# 19 	 12
# 20 	 133
# 21 	 254
# 22 	 119
# 23 	 240
# 24 	 105
# 25 	 226
# 26 	 91
# 27 	 212
# 28 	 77
# 29 	 198
# 30 	 63
# 31 	 184
# 32 	 49
# 33 	 170
# 34 	 35
# 35 	 156
# 36 	 21
# 37 	 142
# 38 	 7
# 39 	 128
# 40 	 249
# 41 	 114
# 42 	 235
# 43 	 100
# 44 	 221
# 45 	 86
# 46 	 207
# 47 	 72
# 48 	 193
# 49 	 58
# 50 	 179
# 51 	 44
# 52 	 165
# 53 	 30
# 54 	 151
# 55 	 16
# 56 	 137
# 57 	 2
# 58 	 123
# 59 	 244
# 60 	 109
# 61 	 230
# 62 	 95
# 63 	 216
# 64 	 81
# 65 	 202
# 66 	 67
# 67 	 188
# 68 	 53
# 69 	 174
# 70 	 39
# 71 	 160
# 72 	 25
# 73 	 146
# 74 	 11
# 75 	 132
# 76 	 253
# 77 	 118
# 78 	 239
# 79 	 104
# 80 	 225
# 81 	 90
# 82 	 211
# 83 	 76
# 84 	 197
# 85 	 62
# 86 	 183
# 87 	 48
# 88 	 169
# 89 	 34
# 90 	 155
# 91 	 20
# 92 	 141
# 93 	 6
# 94 	 127
# ...
